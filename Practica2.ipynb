# %% [markdown]
# <a href="https://colab.research.google.com/github/JesusContr/Mineria-de-datos/blob/main/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
url= 'https://raw.githubusercontent.com/JesusContr/InteligenciaArtificial/main/FullData.csv'
df= pd.read_csv(url)
print(df.head(5))

df.info()

df.drop (columns=['Short_Pass','Long_Pass', 'Acceleration', 'Curve', 'Volleys', 'Freekick_Accuracy', 'Preffered_Foot', 'Work_Rate', 'Skill_Moves', 'Stamina', 'Sliding_Tackle', 'Standing_Tackle', 'Ball_Control', 'Marking', 'Reactions', 'Attacking_Position', 'Interceptions', 'Composure' ], inplace=True)
print('---------------------------------------------------------------------------------------------------\n',
      df.shape,
      '\n---------------------------------------------------------------------------------------------------')

df.info()

cols_cat = ['Nationality','Club','Club_Position', 'National_Position']
for col in cols_cat:
        print(f'Columna {col}: {df[col].nunique()} subniveles')

print('---------------------------------------------------------------------------------------------------\n',
      df.describe(),
      '\n---------------------------------------------------------------------------------------------------')

print(f'DF antes de eliminar las filas repetidas: {df.shape}')
df.drop_duplicates(inplace=True)
print(f'DF después de eliminar las filas repetidas: {df.shape}')

print('--------------------------------------------------------------------------------------------------------------------------------------------------------------\n',
      df.head(),
      '\n-----------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#    ... Long_Shots Curve Freekick_Accuracy Penalties  Volleys GK_Positioning  \
# ...
